# %%
import pandas as pd
import numpy as np
from math import sqrt
from pandas.io import sql
import pymysql.cursors

# Connect to the database
# connection = pymysql.connect(host='localhost',
#                              user='root',
#                              password='anoop4488',
#                              db='flaskapp',
#                              cursorclass=pymysql.cursors.DictCursor)

# %%
ratings_list = [i.strip().split("::") for i in open('./ml-1m/ratings.dat', 'r').readlines()]
users_list = [i.strip().split("::") for i in open('./ml-1m/users.dat', 'r').readlines()]
movies_list = [i.strip().split("::") for i in open('./ml-1m/movies.dat', 'r', encoding='latin-1').readlines()]

ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = int)
movies_df = pd.DataFrame(movies_list, columns = ['MovieID', 'Title', 'Genres'])
# UserID::Gender::Age::Occupation::Zip-code
users_df = pd.DataFrame(users_list, columns = ['UserID', 'Gender', 'Age', 'Occupation', 'ZipCode'])
movies_df['MovieID'] = movies_df['MovieID'].apply(pd.to_numeric)

# %%
users_df.head()
# Out:
#   UserID Gender Age Occupation ZipCode
# 0      1      F   1         10   48067
# 1      2      M  56         16   70072
# 2      3      M  25         15   55117
# 3      4      M  45          7   02460
# 4      5      M  25         20   55455

# %%
movies_df['Title'] = movies_df['Title'].str.replace(r"\(.*\)","")

# %%
# print(movies_df.head())

# %%
# for row in movies_df.itertuples():
#     print row
# Out:
# MovieID                              1
# Title                       Toy Story
# Genres     Animation|Children's|Comedy
# Name: 0, dtype: object
# MovieID                               2
# Title                          Jumanji
# Genres     Adventure|Children's|Fantasy
# Name: 1, dtype: object
# MovieID                    3
# Title      Grumpier Old Men
# Genres        Comedy|Romance
# Name: 2, dtype: object
# MovieID                     4
# Title      Waiting to Exhale
# Genres           Comedy|Drama
# Name: 3, dtype: object
# MovieID                               5
# Title      Father of the Bride Part II
# Genres                           Comedy
# Name: 4, dtype: object
# MovieID                        6
# Title                      Heat
# Genres     Action|Crime|Thriller
# Name: 5, dtype: object
# MovieID                 7
# Title            Sabrina
# Genres     Comedy|Romance
# Name: 6, dtype: object
# MovieID                       8
# Title             Tom and Huck
# ...

# %%
movies_df.to_sql('movies', connection, flavor='mysql', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b5362230e2f9> in <module>()
# ----> 1 movies_df.to_sql('movies', connection, flavor='mysql', if_exists='replace')
#
# NameError: name 'connection' is not defined

# %%
from pandas.io import sql


##############################################################
            #MYSQL CONNECTION
##############################################################
from sqlalchemy import create_engine
from sqlalchemy import MetaData, Table
engine = create_engine('mysql+mysqlconnector://root:anoop4488@localhost/flaskapp')

connection = engine.connect()

# %%
movies_df
# Out:
#       MovieID                                   Title  \
# 0           1                              Toy Story
# 1           2                                Jumanji
# 2           3                       Grumpier Old Men
# 3           4                      Waiting to Exhale
# 4           5            Father of the Bride Part II
# 5           6                                   Heat
# 6           7                                Sabrina
# 7           8                           Tom and Huck
# 8           9                           Sudden Death
# 9          10                              GoldenEye
# 10         11                American President, The
# 11         12            Dracula: Dead and Loving It
# 12         13                                  Balto
# 13         14                                  Nixon
# 14         15                       Cutthroat Island
# 15         16                                 Casino
# 16         17                  Sense and Sensibility
# ...

# %%
movies_df.to_sql('movies', engine, if_exists='replace', index=False, chunksize = 1000)

# %%
ratings_df
# Out:
#          UserID  MovieID  Rating  Timestamp
# 0             1     1193       5  978300760
# 1             1      661       3  978302109
# 2             1      914       3  978301968
# 3             1     3408       4  978300275
# 4             1     2355       5  978824291
# 5             1     1197       3  978302268
# 6             1     1287       5  978302039
# 7             1     2804       5  978300719
# 8             1      594       4  978302268
# 9             1      919       4  978301368
# 10            1      595       5  978824268
# 11            1      938       4  978301752
# 12            1     2398       4  978302281
# 13            1     2918       4  978302124
# 14            1     1035       5  978301753
# 15            1     2791       4  978302188
# 16            1     2687       3  978824268
# 17            1     2018       4  978301777
# 18            1     3105       5  978301713
# 19            1     2797       4  978302039
# ...

# %%
 ratings_df.to_sql('userRatings', engine, if_exists='replace', index=False, chunksize = 1000)

# %%
users_df.to_sql('userData', engine, if_exists='replace', index=False, chunksize = 1000)
